# %% [markdown]
# <a href="https://colab.research.google.com/github/CoolkidSaint/Finally-/blob/main/Stemma10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Define prefixes to remove
prefixes = ["me", "wo", "ɔ", "yɛ", "bɛ", "re", "a", "mo", "wɔn"]

# Define 100 Twi words
words = [
    "mekɔ", "rekɔ", "bɛkɔ", "wokɔ", "ɔkɔ", "yɛkɔ",
    "mecom", "rekom", "bɛkom", "wokom", "ɔkom", "yɛkom",
    "mepɛ", "repɛ", "bɛpɛ", "wopɛ", "ɔpɛ", "yepɛ",
    "medidi", "redidi", "bedidi", "wodidi", "ɔdidi", "yedidi",
    "mɛkɔ", "mɛba", "rebɔ", "bɛbɔ", "bɛyɛ", "yɛbɔ",
    "mema", "bɛma", "rebɔ", "yɛma", "bɛdi", "medi",
    "ɔdi", "redi", "woahu", "ɔahu", "mehu", "rehu",
    "mehunu", "rehunu", "mehwe", "yehwe", "woama", "ɔama",
    "meyɛ", "yɛyɛ", "yɛyɛɛ", "rebɔ", "mebɔ", "yɛbɔ",
    "bɛfa", "mefa", "reba", "rewu", "wɔda", "yɛda",
    "meware", "bɛware", "reware", "ɔware", "wɔbɔ", "yɛkyerɛ",
    "ɔkyerɛ", "wokyerɛ", "mekyerɛ", "rekyerɛ", "wokɔda", "ɔkɔda",
    "wokɔso", "ɔkɔso", "rekɔso", "yɛda", "wɔreba", "ɔreba",
    "bɛreba", "wɔkɔ", "ɔkɔ", "wokɔ", "wokɔɔ", "ɔbɛkɔ",
    "wobɛkɔ", "mobɛkɔ", "wɔbɛkɔ", "yɛbɛkɔ", "wɔbɛfa", "yɛbɛfa",
    "mobɛfa", "ɔbɛfa", "meyɛ", "yɛyɛ", "meba", "woba"
]

# Define stemmer function
def stem_twi(word):
    for prefix in sorted(prefixes, key=len, reverse=True):
        if word.startswith(prefix):
            return word[len(prefix):]
    return word

# Apply stemming
stemmed_words = [(word, stem_twi(word)) for word in words]
df = pd.DataFrame(stemmed_words, columns=["Original Word", "Stemmed"])

# Command-line UI
print("Twi Word Stemmatization App")
print("This app demonstrates simple stemming by removing common Twi prefixes.")
print("\nStemmatized Words Table:")
print(df.to_string(index=False))

# Allow user to enter their own word
print("\nTry it yourself")
user_input = input("Enter a Twi word: ").strip()
if user_input:
    stemmed = stem_twi(user_input)
    print(f"Stemmed version: {stemmed}")
# Out:
# Twi Word Stemmatization App
# This app demonstrates simple stemming by removing common Twi prefixes.
#
# Stemmatized Words Table:
# Original Word Stemmed
#          mekɔ      kɔ
#          rekɔ      kɔ
#          bɛkɔ      kɔ
#          wokɔ      kɔ
#           ɔkɔ      kɔ
#          yɛkɔ      kɔ
#         mecom     com
#         rekom     kom
#         bɛkom     kom
#         wokom     kom
#          ɔkom     kom
#         yɛkom     kom
#          mepɛ      pɛ
#          repɛ      pɛ
#          bɛpɛ      pɛ
#          wopɛ      pɛ
#           ɔpɛ      pɛ
#          yepɛ    yepɛ
#        medidi    didi
#        redidi    didi
#        bedidi  bedidi
#        wodidi    didi
#         ɔdidi    didi
#        yedidi  yedidi
#          mɛkɔ    mɛkɔ
#          mɛba    mɛba
#          rebɔ      bɔ
#          bɛbɔ      bɔ
#          bɛyɛ      yɛ
#          yɛbɔ      bɔ
#          mema      ma
#          bɛma      ma
#          rebɔ      bɔ
#          yɛma      ma
#          bɛdi      di
#          medi      di
#           ɔdi      di
#          redi      di
#         woahu     ahu
#          ɔahu     ahu
#          mehu      hu
#          rehu      hu
#        mehunu    hunu
#        rehunu    hunu
#         mehwe     hwe
#         yehwe   yehwe
#         woama     ama
#          ɔama     ama
#          meyɛ      yɛ
#          yɛyɛ      yɛ
#         yɛyɛɛ     yɛɛ
#          rebɔ      bɔ
#          mebɔ      bɔ
#          yɛbɔ      bɔ
#          bɛfa      fa
#          mefa      fa
#          reba      ba
#          rewu      wu
#          wɔda    wɔda
#          yɛda      da
#        meware    ware
#        bɛware    ware
#        reware    ware
#         ɔware    ware
#          wɔbɔ    wɔbɔ
#       yɛkyerɛ   kyerɛ
#        ɔkyerɛ   kyerɛ
#       wokyerɛ   kyerɛ
#       mekyerɛ   kyerɛ
#       rekyerɛ   kyerɛ
#        wokɔda    kɔda
#         ɔkɔda    kɔda
#        wokɔso    kɔso
#         ɔkɔso    kɔso
#        rekɔso    kɔso
#          yɛda      da
#        wɔreba  wɔreba
#         ɔreba    reba
#        bɛreba    reba
#          wɔkɔ    wɔkɔ
#           ɔkɔ      kɔ
#          wokɔ      kɔ
#         wokɔɔ     kɔɔ
#         ɔbɛkɔ    bɛkɔ
#        wobɛkɔ    bɛkɔ
#        mobɛkɔ    bɛkɔ
#        wɔbɛkɔ  wɔbɛkɔ
#        yɛbɛkɔ    bɛkɔ
#        wɔbɛfa  wɔbɛfa
#        yɛbɛfa    bɛfa
#        mobɛfa    bɛfa
#         ɔbɛfa    bɛfa
#          meyɛ      yɛ
#          yɛyɛ      yɛ
#          meba      ba
#          woba      ba
#
# Try it yourself
